# %% [markdown]
# Найдите список всех самолетов, находящихся сейчас в воздухе. (Имеется в виду на момент выполнения домашки)
#
# Возможно вам поможет это: https://aviationstack.com/documentation

# %%
api_key = 'b29c58e1180d4641a0fc30fbf862c203'

# %%
import requests
import json
import pandas as pd

# %%
url = 'http://api.aviationstack.com/v1/flights'
planes = json.loads(requests.get(url, params={
    'access_key': api_key,
    'flight_status': 'active'
}).content)

# %%
planes # посмотрим на json
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 15658},
#  'data': [{'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Baghdad International',
#     'timezone': 'Asia/Baghdad',
#     'iata': 'BGW',
#     'icao': 'ORBI',
#     'terminal': None,
#     'gate': None,
#     'delay': 12,
#     'scheduled': '2021-12-02T10:00:00+00:00',
#     'estimated': '2021-12-02T10:00:00+00:00',
#     'actual': '2021-12-02T10:11:00+00:00',
#     'estimated_runway': '2021-12-02T10:11:00+00:00',
#     'actual_runway': '2021-12-02T10:11:00+00:00'},
#    'arrival': {'airport': 'Cairo International Airport',
#     'timezone': 'Africa/Cairo',
#     'iata': 'CAI',
#     'icao': 'HECA',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:30:00+00:00',
#     'estimated': '2021-12-02T11:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Iraqi Airways', 'iata': 'IA', 'icao': 'IAW'},
#    'flight': {'number': '101',
#     'iata': 'IA101',
#     'icao': 'IAW101',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'C62',
#     'delay': 30,
#     'scheduled': '2021-12-02T07:05:00+00:00',
#     'estimated': '2021-12-02T07:05:00+00:00',
#     'actual': '2021-12-02T07:50:00+00:00',
#     'estimated_runway': '2021-12-02T07:50:00+00:00',
#     'actual_runway': '2021-12-02T07:50:00+00:00'},
#    'arrival': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': 5,
#     'scheduled': '2021-12-02T09:50:00+00:00',
#     'estimated': '2021-12-02T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'},
#    'flight': {'number': '902',
#     'iata': 'BA902',
#     'icao': 'BAW902',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Srinagar',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'SXR',
#     'icao': 'VISR',
#     'terminal': None,
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2021-12-02T13:25:00+00:00',
#     'estimated': '2021-12-02T13:25:00+00:00',
#     'actual': '2021-12-02T13:25:00+00:00',
#     'estimated_runway': '2021-12-02T13:25:00+00:00',
#     'actual_runway': '2021-12-02T13:25:00+00:00'},
#    'arrival': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': '6',
#     'baggage': '6',
#     'delay': None,
#     'scheduled': '2021-12-02T15:00:00+00:00',
#     'estimated': '2021-12-02T15:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'AirAsia India', 'iata': 'I5', 'icao': 'IAD'},
#    'flight': {'number': '559',
#     'iata': 'I5559',
#     'icao': 'IAD559',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Oliver Reginald Tambo International (Jan Smuts International)',
#     'timezone': 'Africa/Johannesburg',
#     'iata': 'JNB',
#     'icao': 'FAOR',
#     'terminal': 'B',
#     'gate': 'D3',
#     'delay': 18,
#     'scheduled': '2021-12-02T10:00:00+00:00',
#     'estimated': '2021-12-02T10:00:00+00:00',
#     'actual': '2021-12-02T10:18:00+00:00',
#     'estimated_runway': '2021-12-02T10:18:00+00:00',
#     'actual_runway': '2021-12-02T10:18:00+00:00'},
#    'arrival': {'airport': 'Cape Town International',
#     'timezone': 'Africa/Johannesburg',
#     'iata': 'CPT',
#     'icao': 'FACT',
#     'terminal': 'B',
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2021-12-02T12:10:00+00:00',
#     'estimated': '2021-12-02T12:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Global Aviation Operations',
#     'iata': 'GE',
#     'icao': 'GBB'},
#    'flight': {'number': '131',
#     'iata': 'GE131',
#     'icao': 'GBB131',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Luton Airport',
#     'timezone': 'Europe/London',
#     'iata': 'LTN',
#     'icao': 'EGGW',
#     'terminal': None,
#     'gate': None,
#     'delay': 35,
#     'scheduled': '2021-12-02T05:50:00+00:00',
#     'estimated': '2021-12-02T05:50:00+00:00',
#     'actual': '2021-12-02T06:24:00+00:00',
#     'estimated_runway': '2021-12-02T06:24:00+00:00',
#     'actual_runway': '2021-12-02T06:24:00+00:00'},
#    'arrival': {'airport': 'Snilow',
#     'timezone': 'Europe/Kiev',
#     'iata': 'LWO',
#     'icao': 'UKLL',
#     'terminal': 'A',
#     'gate': None,
#     'baggage': None,
#     'delay': 15,
#     'scheduled': '2021-12-02T10:30:00+00:00',
#     'estimated': '2021-12-02T10:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'},
#    'flight': {'number': '4485',
#     'iata': 'W64485',
#     'icao': 'WZZ4485',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': '24',
#     'delay': 18,
#     'scheduled': '2021-12-02T14:55:00+00:00',
#     'estimated': '2021-12-02T14:55:00+00:00',
#     'actual': '2021-12-02T15:12:00+00:00',
#     'estimated_runway': '2021-12-02T15:12:00+00:00',
#     'actual_runway': '2021-12-02T15:12:00+00:00'},
#    'arrival': {'airport': 'Akita',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'AXT',
#     'icao': 'RJSK',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T16:05:00+00:00',
#     'estimated': '2021-12-02T16:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Hawaiian Airlines', 'iata': 'HA', 'icao': 'HAL'},
#    'flight': {'number': '5062',
#     'iata': 'HA5062',
#     'icao': 'HAL5062',
#     'codeshared': {'airline_name': 'jal',
#      'airline_iata': 'jl',
#      'airline_icao': 'jal',
#      'flight_number': '165',
#      'flight_iata': 'jl165',
#      'flight_icao': 'jal165'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Jinjiang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JJN',
#     'icao': 'ZSQZ',
#     'terminal': None,
#     'gate': '12',
#     'delay': 2,
#     'scheduled': '2021-12-02T07:50:00+00:00',
#     'estimated': '2021-12-02T07:50:00+00:00',
#     'actual': '2021-12-02T07:51:00+00:00',
#     'estimated_runway': '2021-12-02T07:51:00+00:00',
#     'actual_runway': '2021-12-02T07:51:00+00:00'},
#    'arrival': {'airport': 'Jinan',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'TNA',
#     'icao': 'ZSJN',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T10:00:00+00:00',
#     'estimated': '2021-12-02T10:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'},
#    'flight': {'number': '8241',
#     'iata': 'MF8241',
#     'icao': 'CXA8241',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-5488',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '7805D5'},
#    'live': {'updated': '2021-12-02T00:36:27+00:00',
#     'latitude': 28.94,
#     'longitude': 117.39,
#     'altitude': 9784.08,
#     'direction': 345,
#     'speed_horizontal': 685.24,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Cairns',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'CNS',
#     'icao': 'YBCS',
#     'terminal': '2',
#     'gate': '16',
#     'delay': None,
#     'scheduled': '2021-12-02T11:00:00+00:00',
#     'estimated': '2021-12-02T11:00:00+00:00',
#     'actual': '2021-12-02T10:58:00+00:00',
#     'estimated_runway': '2021-12-02T10:58:00+00:00',
#     'actual_runway': '2021-12-02T10:58:00+00:00'},
#    'arrival': {'airport': 'Weipa',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'WEI',
#     'icao': 'YBWP',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T12:30:00+00:00',
#     'estimated': '2021-12-02T12:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'},
#    'flight': {'number': '2478',
#     'iata': 'QF2478',
#     'icao': 'QFA2478',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Sheremetyevo International',
#     'timezone': 'Europe/Moscow',
#     'iata': 'SVO',
#     'icao': 'UUEE',
#     'terminal': 'B',
#     'gate': '105',
#     'delay': 18,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': '2021-12-02T10:27:00+00:00',
#     'estimated_runway': '2021-12-02T10:27:00+00:00',
#     'actual_runway': '2021-12-02T10:27:00+00:00'},
#    'arrival': {'airport': 'Kurumoch',
#     'timezone': 'Europe/Samara',
#     'iata': 'KUF',
#     'icao': 'UWWW',
#     'terminal': 'B',
#     'gate': None,
#     'baggage': 'B2',
#     'delay': None,
#     'scheduled': '2021-12-02T13:05:00+00:00',
#     'estimated': '2021-12-02T13:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Aeroflot', 'iata': 'SU', 'icao': 'AFL'},
#    'flight': {'number': '1604',
#     'iata': 'SU1604',
#     'icao': 'AFL1604',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Sheremetyevo International',
#     'timezone': 'Europe/Moscow',
#     'iata': 'SVO',
#     'icao': 'UUEE',
#     'terminal': 'C',
#     'gate': '130',
#     'delay': 41,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': '2021-12-02T10:50:00+00:00',
#     'estimated_runway': '2021-12-02T10:50:00+00:00',
#     'actual_runway': '2021-12-02T10:50:00+00:00'},
#    'arrival': {'airport': 'Larnaca',
#     'timezone': 'Asia/Nicosia',
#     'iata': 'LCA',
#     'icao': 'LCLK',
#     'terminal': None,
#     'gate': None,
#     'baggage': 'C1',
#     'delay': 1,
#     'scheduled': '2021-12-02T13:15:00+00:00',
#     'estimated': '2021-12-02T13:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Aeroflot', 'iata': 'SU', 'icao': 'AFL'},
#    'flight': {'number': '2072',
#     'iata': 'SU2072',
#     'icao': 'AFL2072',
#     'codeshared': None},
#    'aircraft': {'registration': 'VP-BFK',
#     'iata': 'A321',
#     'icao': 'A321',
#     'icao24': '42434C'},
#    'live': {'updated': '2021-12-02T09:01:29+00:00',
#     'latitude': 48.75,
#     'longitude': 40.65,
#     'altitude': 10332.7,
#     'direction': 192,
#     'speed_horizontal': 892.664,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Boa Vista',
#     'timezone': 'America/Boa_Vista',
#     'iata': 'BVB',
#     'icao': 'SBBV',
#     'terminal': None,
#     'gate': '1',
#     'delay': 7,
#     'scheduled': '2021-12-02T03:05:00+00:00',
#     'estimated': '2021-12-02T03:05:00+00:00',
#     'actual': '2021-12-02T03:12:00+00:00',
#     'estimated_runway': '2021-12-02T03:12:00+00:00',
#     'actual_runway': '2021-12-02T03:12:00+00:00'},
#    'arrival': {'airport': 'Presidente Juscelino Kubitschek',
#     'timezone': 'America/Sao_Paulo',
#     'iata': 'BSB',
#     'icao': 'SBBR',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T07:40:00+00:00',
#     'estimated': '2021-12-02T07:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Gol', 'iata': 'G3', 'icao': 'GLO'},
#    'flight': {'number': '1819',
#     'iata': 'G31819',
#     'icao': 'GLO1819',
#     'codeshared': None},
#    'aircraft': {'registration': 'PR-XMT',
#     'iata': 'B38M',
#     'icao': 'B38M',
#     'icao24': 'E49526'},
#    'live': {'updated': '2021-12-02T07:16:25+00:00',
#     'latitude': 2.75,
#     'longitude': -60.61,
#     'altitude': 2400.3,
#     'direction': 200,
#     'speed_horizontal': 527.82,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Bangalore International Airport',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'BLR',
#     'icao': 'VOBL',
#     'terminal': None,
#     'gate': '14',
#     'delay': 22,
#     'scheduled': '2021-12-02T11:20:00+00:00',
#     'estimated': '2021-12-02T11:20:00+00:00',
#     'actual': '2021-12-02T11:41:00+00:00',
#     'estimated_runway': '2021-12-02T11:41:00+00:00',
#     'actual_runway': '2021-12-02T11:41:00+00:00'},
#    'arrival': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': '6',
#     'baggage': '6',
#     'delay': None,
#     'scheduled': '2021-12-02T14:05:00+00:00',
#     'estimated': '2021-12-02T14:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'AirAsia India', 'iata': 'I5', 'icao': 'IAD'},
#    'flight': {'number': '741',
#     'iata': 'I5741',
#     'icao': 'IAD741',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2F',
#     'gate': 'F33',
#     'delay': 16,
#     'scheduled': '2021-12-02T08:50:00+00:00',
#     'estimated': '2021-12-02T08:50:00+00:00',
#     'actual': '2021-12-02T09:06:00+00:00',
#     'estimated_runway': '2021-12-02T09:06:00+00:00',
#     'actual_runway': '2021-12-02T09:06:00+00:00'},
#    'arrival': {'airport': 'Mérignac',
#     'timezone': 'Europe/Paris',
#     'iata': 'BOD',
#     'icao': 'LFBD',
#     'terminal': 'B',
#     'gate': '1',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Kenya Airways', 'iata': 'KQ', 'icao': 'KQA'},
#    'flight': {'number': '3008',
#     'iata': 'KQ3008',
#     'icao': 'KQA3008',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '7620',
#      'flight_iata': 'af7620',
#      'flight_icao': 'afr7620'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2F',
#     'gate': 'F33',
#     'delay': 16,
#     'scheduled': '2021-12-02T08:50:00+00:00',
#     'estimated': '2021-12-02T08:50:00+00:00',
#     'actual': '2021-12-02T09:06:00+00:00',
#     'estimated_runway': '2021-12-02T09:06:00+00:00',
#     'actual_runway': '2021-12-02T09:06:00+00:00'},
#    'arrival': {'airport': 'Mérignac',
#     'timezone': 'Europe/Paris',
#     'iata': 'BOD',
#     'icao': 'LFBD',
#     'terminal': 'B',
#     'gate': '1',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Mauritius', 'iata': 'MK', 'icao': 'MAU'},
#    'flight': {'number': '9018',
#     'iata': 'MK9018',
#     'icao': 'MAU9018',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '7620',
#      'flight_iata': 'af7620',
#      'flight_icao': 'afr7620'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2F',
#     'gate': 'F33',
#     'delay': 16,
#     'scheduled': '2021-12-02T08:50:00+00:00',
#     'estimated': '2021-12-02T08:50:00+00:00',
#     'actual': '2021-12-02T09:06:00+00:00',
#     'estimated_runway': '2021-12-02T09:06:00+00:00',
#     'actual_runway': '2021-12-02T09:06:00+00:00'},
#    'arrival': {'airport': 'Mérignac',
#     'timezone': 'Europe/Paris',
#     'iata': 'BOD',
#     'icao': 'LFBD',
#     'terminal': 'B',
#     'gate': '1',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'},
#    'flight': {'number': '1537',
#     'iata': 'MU1537',
#     'icao': 'CES1537',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '7620',
#      'flight_iata': 'af7620',
#      'flight_icao': 'afr7620'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2F',
#     'gate': 'F33',
#     'delay': 16,
#     'scheduled': '2021-12-02T08:50:00+00:00',
#     'estimated': '2021-12-02T08:50:00+00:00',
#     'actual': '2021-12-02T09:06:00+00:00',
#     'estimated_runway': '2021-12-02T09:06:00+00:00',
#     'actual_runway': '2021-12-02T09:06:00+00:00'},
#    'arrival': {'airport': 'Mérignac',
#     'timezone': 'Europe/Paris',
#     'iata': 'BOD',
#     'icao': 'LFBD',
#     'terminal': 'B',
#     'gate': '1',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Aeroflot', 'iata': 'SU', 'icao': 'AFL'},
#    'flight': {'number': '3034',
#     'iata': 'SU3034',
#     'icao': 'AFL3034',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '7620',
#      'flight_iata': 'af7620',
#      'flight_icao': 'afr7620'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2F',
#     'gate': 'F33',
#     'delay': 16,
#     'scheduled': '2021-12-02T08:50:00+00:00',
#     'estimated': '2021-12-02T08:50:00+00:00',
#     'actual': '2021-12-02T09:06:00+00:00',
#     'estimated_runway': '2021-12-02T09:06:00+00:00',
#     'actual_runway': '2021-12-02T09:06:00+00:00'},
#    'arrival': {'airport': 'Mérignac',
#     'timezone': 'Europe/Paris',
#     'iata': 'BOD',
#     'icao': 'LFBD',
#     'terminal': 'B',
#     'gate': '1',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2021-12-02T10:10:00+00:00',
#     'estimated': '2021-12-02T10:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Virgin Atlantic', 'iata': 'VS', 'icao': 'VIR'},
#    'flight': {'number': '6185',
#     'iata': 'VS6185',
#     'icao': 'VIR6185',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '7620',
#      'flight_iata': 'af7620',
#      'flight_icao': 'afr7620'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '1',
#     'gate': 'A30',
#     'delay': 10,
#     'scheduled': '2021-12-02T08:35:00+00:00',
#     'estimated': '2021-12-02T08:35:00+00:00',
#     'actual': '2021-12-02T08:45:00+00:00',
#     'estimated_runway': '2021-12-02T08:45:00+00:00',
#     'actual_runway': '2021-12-02T08:45:00+00:00'},
#    'arrival': {'airport': 'Marseille Provence Airport',
#     'timezone': 'Europe/Paris',
#     'iata': 'MRS',
#     'icao': 'LFML',
#     'terminal': '1A',
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2021-12-02T10:05:00+00:00',
#     'estimated': '2021-12-02T10:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '5873',
#     'iata': 'NH5873',
#     'icao': 'ANA5873',
#     'codeshared': {'airline_name': 'lufthansa',
#      'airline_iata': 'lh',
#      'airline_icao': 'dlh',
#      'flight_number': '1086',
#      'flight_iata': 'lh1086',
#      'flight_icao': 'dlh1086'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': '19',
#     'delay': 28,
#     'scheduled': '2021-12-02T08:40:00+00:00',
#     'estimated': '2021-12-02T08:40:00+00:00',
#     'actual': '2021-12-02T09:08:00+00:00',
#     'estimated_runway': '2021-12-02T09:08:00+00:00',
#     'actual_runway': '2021-12-02T09:08:00+00:00'},
#    'arrival': {'airport': 'Gran Canaria',
#     'timezone': 'Atlantic/Canary',
#     'iata': 'LPA',
#     'icao': 'GCLP',
#     'terminal': '4',
#     'gate': None,
#     'baggage': '37',
#     'delay': 10,
#     'scheduled': '2021-12-02T11:55:00+00:00',
#     'estimated': '2021-12-02T11:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'},
#    'flight': {'number': '5521',
#     'iata': 'FR5521',
#     'icao': 'RYR5521',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': '19',
#     'delay': 8,
#     'scheduled': '2021-12-02T08:35:00+00:00',
#     'estimated': '2021-12-02T08:35:00+00:00',
#     'actual': '2021-12-02T08:42:00+00:00',
#     'estimated_runway': '2021-12-02T08:42:00+00:00',
#     'actual_runway': '2021-12-02T08:42:00+00:00'},
#    'arrival': {'airport': 'Bristol',
#     'timezone': 'Europe/London',
#     'iata': 'BRS',
#     'icao': 'EGGD',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T09:40:00+00:00',
#     'estimated': '2021-12-02T09:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'},
#    'flight': {'number': '1177',
#     'iata': 'FR1177',
#     'icao': 'RYR1177',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': '5',
#     'delay': 6,
#     'scheduled': '2021-12-02T08:40:00+00:00',
#     'estimated': '2021-12-02T08:40:00+00:00',
#     'actual': '2021-12-02T08:45:00+00:00',
#     'estimated_runway': '2021-12-02T08:45:00+00:00',
#     'actual_runway': '2021-12-02T08:45:00+00:00'},
#    'arrival': {'airport': 'Brussels Airport',
#     'timezone': 'Europe/Brussels',
#     'iata': 'BRU',
#     'icao': 'EBBR',
#     'terminal': '2',
#     'gate': 'A42',
#     'baggage': '8',
#     'delay': None,
#     'scheduled': '2021-12-02T10:15:00+00:00',
#     'estimated': '2021-12-02T10:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'},
#    'flight': {'number': '2800',
#     'iata': 'SQ2800',
#     'icao': 'SIA2800',
#     'codeshared': {'airline_name': 'brussels airlines',
#      'airline_iata': 'sn',
#      'airline_icao': 'bel',
#      'flight_number': '3154',
#      'flight_iata': 'sn3154',
#      'flight_icao': 'bel3154'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': '5',
#     'delay': 6,
#     'scheduled': '2021-12-02T08:40:00+00:00',
#     'estimated': '2021-12-02T08:40:00+00:00',
#     'actual': '2021-12-02T08:45:00+00:00',
#     'estimated_runway': '2021-12-02T08:45:00+00:00',
#     'actual_runway': '2021-12-02T08:45:00+00:00'},
#    'arrival': {'airport': 'Brussels Airport',
#     'timezone': 'Europe/Brussels',
#     'iata': 'BRU',
#     'icao': 'EBBR',
#     'terminal': '2',
#     'gate': 'A42',
#     'baggage': '8',
#     'delay': None,
#     'scheduled': '2021-12-02T10:15:00+00:00',
#     'estimated': '2021-12-02T10:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'United Airlines', 'iata': 'UA', 'icao': 'UAL'},
#    'flight': {'number': '9934',
#     'iata': 'UA9934',
#     'icao': 'UAL9934',
#     'codeshared': {'airline_name': 'brussels airlines',
#      'airline_iata': 'sn',
#      'airline_icao': 'bel',
#      'flight_number': '3154',
#      'flight_iata': 'sn3154',
#      'flight_icao': 'bel3154'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': '5',
#     'delay': 6,
#     'scheduled': '2021-12-02T08:40:00+00:00',
#     'estimated': '2021-12-02T08:40:00+00:00',
#     'actual': '2021-12-02T08:45:00+00:00',
#     'estimated_runway': '2021-12-02T08:45:00+00:00',
#     'actual_runway': '2021-12-02T08:45:00+00:00'},
#    'arrival': {'airport': 'Brussels Airport',
#     'timezone': 'Europe/Brussels',
#     'iata': 'BRU',
#     'icao': 'EBBR',
#     'terminal': '2',
#     'gate': 'A42',
#     'baggage': '8',
#     'delay': None,
#     'scheduled': '2021-12-02T10:15:00+00:00',
#     'estimated': '2021-12-02T10:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Brussels Airlines', 'iata': 'SN', 'icao': 'BEL'},
#    'flight': {'number': '3154',
#     'iata': 'SN3154',
#     'icao': 'BEL3154',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Son Sant Joan Airport',
#     'timezone': 'Europe/Madrid',
#     'iata': 'PMI',
#     'icao': 'LEPA',
#     'terminal': None,
#     'gate': '36',
#     'delay': 9,
#     'scheduled': '2021-12-02T08:45:00+00:00',
#     'estimated': '2021-12-02T08:45:00+00:00',
#     'actual': '2021-12-02T08:54:00+00:00',
#     'estimated_runway': '2021-12-02T08:54:00+00:00',
#     'actual_runway': '2021-12-02T08:54:00+00:00'},
#    'arrival': {'airport': 'San Pablo',
#     'timezone': 'Europe/Madrid',
#     'iata': 'SVQ',
#     'icao': 'LEZL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '2',
#     'delay': None,
#     'scheduled': '2021-12-02T10:20:00+00:00',
#     'estimated': '2021-12-02T10:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'},
#    'flight': {'number': '5273',
#     'iata': 'FR5273',
#     'icao': 'RYR5273',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Son Sant Joan Airport',
#     'timezone': 'Europe/Madrid',
#     'iata': 'PMI',
#     'icao': 'LEPA',
#     'terminal': None,
#     'gate': 'C50',
#     'delay': 16,
#     'scheduled': '2021-12-02T09:00:00+00:00',
#     'estimated': '2021-12-02T09:00:00+00:00',
#     'actual': '2021-12-02T09:15:00+00:00',
#     'estimated_runway': '2021-12-02T09:15:00+00:00',
#     'actual_runway': '2021-12-02T09:15:00+00:00'},
#    'arrival': {'airport': 'Franz Josef Strauss',
#     'timezone': 'Europe/Berlin',
#     'iata': 'MUC',
#     'icao': 'EDDM',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:15:00+00:00',
#     'estimated': '2021-12-02T11:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'},
#    'flight': {'number': '6890',
#     'iata': 'EW6890',
#     'icao': 'EWG6890',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Juzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JUZ',
#     'icao': 'ZSJU',
#     'terminal': None,
#     'gate': '1-3',
#     'delay': 30,
#     'scheduled': '2021-12-02T09:10:00+00:00',
#     'estimated': '2021-12-02T09:10:00+00:00',
#     'actual': '2021-12-02T09:40:00+00:00',
#     'estimated_runway': '2021-12-02T09:40:00+00:00',
#     'actual_runway': '2021-12-02T09:40:00+00:00'},
#    'arrival': {'airport': 'Guiyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KWE',
#     'icao': 'ZUGY',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'delay': 8,
#     'scheduled': '2021-12-02T11:40:00+00:00',
#     'estimated': '2021-12-02T11:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Express Air', 'iata': 'G5', 'icao': 'HXA'},
#    'flight': {'number': '4922',
#     'iata': 'G54922',
#     'icao': 'HXA4922',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Juzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JUZ',
#     'icao': 'ZSJU',
#     'terminal': None,
#     'gate': '1-3',
#     'delay': 30,
#     'scheduled': '2021-12-02T09:10:00+00:00',
#     'estimated': '2021-12-02T09:10:00+00:00',
#     'actual': '2021-12-02T09:40:00+00:00',
#     'estimated_runway': '2021-12-02T09:40:00+00:00',
#     'actual_runway': '2021-12-02T09:40:00+00:00'},
#    'arrival': {'airport': 'Guiyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KWE',
#     'icao': 'ZUGY',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'delay': 8,
#     'scheduled': '2021-12-02T11:40:00+00:00',
#     'estimated': '2021-12-02T11:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Sichuan Airlines', 'iata': '3U', 'icao': 'CSC'},
#    'flight': {'number': '4618',
#     'iata': '3U4618',
#     'icao': 'CSC4618',
#     'codeshared': {'airline_name': 'china express air',
#      'airline_iata': 'g5',
#      'airline_icao': 'hxa',
#      'flight_number': '4922',
#      'flight_iata': 'g54922',
#      'flight_icao': 'hxa4922'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Juzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JUZ',
#     'icao': 'ZSJU',
#     'terminal': None,
#     'gate': '1-3',
#     'delay': 30,
#     'scheduled': '2021-12-02T09:10:00+00:00',
#     'estimated': '2021-12-02T09:10:00+00:00',
#     'actual': '2021-12-02T09:40:00+00:00',
#     'estimated_runway': '2021-12-02T09:40:00+00:00',
#     'actual_runway': '2021-12-02T09:40:00+00:00'},
#    'arrival': {'airport': 'Guiyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KWE',
#     'icao': 'ZUGY',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'delay': 8,
#     'scheduled': '2021-12-02T11:40:00+00:00',
#     'estimated': '2021-12-02T11:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Kunming Airlines', 'iata': 'KY', 'icao': 'KNA'},
#    'flight': {'number': '5098',
#     'iata': 'KY5098',
#     'icao': 'KNA5098',
#     'codeshared': {'airline_name': 'china express air',
#      'airline_iata': 'g5',
#      'airline_icao': 'hxa',
#      'flight_number': '4922',
#      'flight_iata': 'g54922',
#      'flight_icao': 'hxa4922'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Juzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JUZ',
#     'icao': 'ZSJU',
#     'terminal': None,
#     'gate': '1-3',
#     'delay': 30,
#     'scheduled': '2021-12-02T09:10:00+00:00',
#     'estimated': '2021-12-02T09:10:00+00:00',
#     'actual': '2021-12-02T09:40:00+00:00',
#     'estimated_runway': '2021-12-02T09:40:00+00:00',
#     'actual_runway': '2021-12-02T09:40:00+00:00'},
#    'arrival': {'airport': 'Guiyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KWE',
#     'icao': 'ZUGY',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'delay': 8,
#     'scheduled': '2021-12-02T11:40:00+00:00',
#     'estimated': '2021-12-02T11:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'},
#    'flight': {'number': '4158',
#     'iata': 'MU4158',
#     'icao': 'CES4158',
#     'codeshared': {'airline_name': 'china express air',
#      'airline_iata': 'g5',
#      'airline_icao': 'hxa',
#      'flight_number': '4922',
#      'flight_iata': 'g54922',
#      'flight_icao': 'hxa4922'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Juzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'JUZ',
#     'icao': 'ZSJU',
#     'terminal': None,
#     'gate': '1-3',
#     'delay': 30,
#     'scheduled': '2021-12-02T09:10:00+00:00',
#     'estimated': '2021-12-02T09:10:00+00:00',
#     'actual': '2021-12-02T09:40:00+00:00',
#     'estimated_runway': '2021-12-02T09:40:00+00:00',
#     'actual_runway': '2021-12-02T09:40:00+00:00'},
#    'arrival': {'airport': 'Guiyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KWE',
#     'icao': 'ZUGY',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'delay': 8,
#     'scheduled': '2021-12-02T11:40:00+00:00',
#     'estimated': '2021-12-02T11:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Loong Air', 'iata': 'GJ', 'icao': 'CDC'},
#    'flight': {'number': '5550',
#     'iata': 'GJ5550',
#     'icao': 'CDC5550',
#     'codeshared': {'airline_name': 'china express air',
#      'airline_iata': 'g5',
#      'airline_icao': 'hxa',
#      'flight_number': '4922',
#      'flight_iata': 'g54922',
#      'flight_icao': 'hxa4922'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '3',
#     'gate': 'M',
#     'delay': None,
#     'scheduled': '2021-12-02T09:40:00+00:00',
#     'estimated': '2021-12-02T09:40:00+00:00',
#     'actual': '2021-12-02T09:38:00+00:00',
#     'estimated_runway': '2021-12-02T09:38:00+00:00',
#     'actual_runway': '2021-12-02T09:38:00+00:00'},
#    'arrival': {'airport': 'Xichang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIC',
#     'icao': 'ZUXC',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:45:00+00:00',
#     'estimated': '2021-12-02T11:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Sichuan Airlines', 'iata': '3U', 'icao': 'CSC'},
#    'flight': {'number': '3406',
#     'iata': '3U3406',
#     'icao': 'CSC3406',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': 'D',
#     'delay': 3,
#     'scheduled': '2021-12-02T09:40:00+00:00',
#     'estimated': '2021-12-02T09:40:00+00:00',
#     'actual': '2021-12-02T09:43:00+00:00',
#     'estimated_runway': '2021-12-02T09:43:00+00:00',
#     'actual_runway': '2021-12-02T09:43:00+00:00'},
#    'arrival': {'airport': 'Fuyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'FUG',
#     'icao': 'ZSFY',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:20:00+00:00',
#     'estimated': '2021-12-02T11:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Spring Airlines', 'iata': '9C', 'icao': 'CQH'},
#    'flight': {'number': '6697',
#     'iata': '9C6697',
#     'icao': 'CQH6697',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '3',
#     'gate': 'M',
#     'delay': 1,
#     'scheduled': '2021-12-02T09:50:00+00:00',
#     'estimated': '2021-12-02T09:50:00+00:00',
#     'actual': '2021-12-02T09:50:00+00:00',
#     'estimated_runway': '2021-12-02T09:50:00+00:00',
#     'actual_runway': '2021-12-02T09:50:00+00:00'},
#    'arrival': {'airport': 'Altay',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'AAT',
#     'icao': 'ZWAT',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T13:35:00+00:00',
#     'estimated': '2021-12-02T13:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'},
#    'flight': {'number': '9383',
#     'iata': 'CZ9383',
#     'icao': 'CSN9383',
#     'codeshared': {'airline_name': 'sichuan airlines',
#      'airline_iata': '3u',
#      'airline_icao': 'csc',
#      'flight_number': '8493',
#      'flight_iata': '3u8493',
#      'flight_icao': 'csc8493'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '3',
#     'gate': 'M',
#     'delay': 1,
#     'scheduled': '2021-12-02T09:50:00+00:00',
#     'estimated': '2021-12-02T09:50:00+00:00',
#     'actual': '2021-12-02T09:50:00+00:00',
#     'estimated_runway': '2021-12-02T09:50:00+00:00',
#     'actual_runway': '2021-12-02T09:50:00+00:00'},
#    'arrival': {'airport': 'Altay',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'AAT',
#     'icao': 'ZWAT',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T13:35:00+00:00',
#     'estimated': '2021-12-02T13:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'},
#    'flight': {'number': '5262',
#     'iata': 'MF5262',
#     'icao': 'CXA5262',
#     'codeshared': {'airline_name': 'sichuan airlines',
#      'airline_iata': '3u',
#      'airline_icao': 'csc',
#      'flight_number': '8493',
#      'flight_iata': '3u8493',
#      'flight_icao': 'csc8493'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '3',
#     'gate': 'M',
#     'delay': 1,
#     'scheduled': '2021-12-02T09:50:00+00:00',
#     'estimated': '2021-12-02T09:50:00+00:00',
#     'actual': '2021-12-02T09:50:00+00:00',
#     'estimated_runway': '2021-12-02T09:50:00+00:00',
#     'actual_runway': '2021-12-02T09:50:00+00:00'},
#    'arrival': {'airport': 'Altay',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'AAT',
#     'icao': 'ZWAT',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T13:35:00+00:00',
#     'estimated': '2021-12-02T13:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Sichuan Airlines', 'iata': '3U', 'icao': 'CSC'},
#    'flight': {'number': '8493',
#     'iata': '3U8493',
#     'icao': 'CSC8493',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-8372',
#     'iata': 'A320',
#     'icao': 'A320',
#     'icao24': '780F34'},
#    'live': {'updated': '2021-12-02T03:46:56+00:00',
#     'latitude': 42.54,
#     'longitude': 98.09,
#     'altitude': 8572.5,
#     'direction': 310,
#     'speed_horizontal': 722.28,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': None,
#     'delay': 14,
#     'scheduled': '2021-12-02T09:55:00+00:00',
#     'estimated': '2021-12-02T09:55:00+00:00',
#     'actual': '2021-12-02T10:08:00+00:00',
#     'estimated_runway': '2021-12-02T10:08:00+00:00',
#     'actual_runway': '2021-12-02T10:08:00+00:00'},
#    'arrival': {'airport': 'Shihezi Huayuan Airport',
#     'timezone': None,
#     'iata': 'SHF',
#     'icao': 'ZWHZ',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T14:00:00+00:00',
#     'estimated': '2021-12-02T14:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': '9 Air Co', 'iata': 'AQ', 'icao': 'JYH'},
#    'flight': {'number': '1351',
#     'iata': 'AQ1351',
#     'icao': 'JYH1351',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': '13',
#     'delay': 18,
#     'scheduled': '2021-12-02T09:55:00+00:00',
#     'estimated': '2021-12-02T09:55:00+00:00',
#     'actual': '2021-12-02T09:51:00+00:00',
#     'estimated_runway': '2021-12-02T09:51:00+00:00',
#     'actual_runway': '2021-12-02T09:51:00+00:00'},
#    'arrival': {'airport': 'Longnan Chengzhou Airport',
#     'timezone': None,
#     'iata': 'LNL',
#     'icao': 'ZLLN',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:25:00+00:00',
#     'estimated': '2021-12-02T11:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air China LTD', 'iata': 'CA', 'icao': 'CCA'},
#    'flight': {'number': '8819',
#     'iata': 'CA8819',
#     'icao': 'CCA8819',
#     'codeshared': {'airline_name': 'shandong airlines',
#      'airline_iata': 'sc',
#      'airline_icao': 'cdg',
#      'flight_number': '8819',
#      'flight_iata': 'sc8819',
#      'flight_icao': 'cdg8819'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': '13',
#     'delay': 18,
#     'scheduled': '2021-12-02T09:55:00+00:00',
#     'estimated': '2021-12-02T09:55:00+00:00',
#     'actual': '2021-12-02T09:51:00+00:00',
#     'estimated_runway': '2021-12-02T09:51:00+00:00',
#     'actual_runway': '2021-12-02T09:51:00+00:00'},
#    'arrival': {'airport': 'Longnan Chengzhou Airport',
#     'timezone': None,
#     'iata': 'LNL',
#     'icao': 'ZLLN',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:25:00+00:00',
#     'estimated': '2021-12-02T11:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Tibet Airlines', 'iata': 'TV', 'icao': 'TBA'},
#    'flight': {'number': '6869',
#     'iata': 'TV6869',
#     'icao': 'TBA6869',
#     'codeshared': {'airline_name': 'shandong airlines',
#      'airline_iata': 'sc',
#      'airline_icao': 'cdg',
#      'flight_number': '8819',
#      'flight_iata': 'sc8819',
#      'flight_icao': 'cdg8819'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': '13',
#     'delay': 18,
#     'scheduled': '2021-12-02T09:55:00+00:00',
#     'estimated': '2021-12-02T09:55:00+00:00',
#     'actual': '2021-12-02T09:51:00+00:00',
#     'estimated_runway': '2021-12-02T09:51:00+00:00',
#     'actual_runway': '2021-12-02T09:51:00+00:00'},
#    'arrival': {'airport': 'Longnan Chengzhou Airport',
#     'timezone': None,
#     'iata': 'LNL',
#     'icao': 'ZLLN',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:25:00+00:00',
#     'estimated': '2021-12-02T11:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Express Air', 'iata': 'G5', 'icao': 'HXA'},
#    'flight': {'number': '8454',
#     'iata': 'G58454',
#     'icao': 'HXA8454',
#     'codeshared': {'airline_name': 'shandong airlines',
#      'airline_iata': 'sc',
#      'airline_icao': 'cdg',
#      'flight_number': '8819',
#      'flight_iata': 'sc8819',
#      'flight_icao': 'cdg8819'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': '13',
#     'delay': 18,
#     'scheduled': '2021-12-02T09:55:00+00:00',
#     'estimated': '2021-12-02T09:55:00+00:00',
#     'actual': '2021-12-02T09:51:00+00:00',
#     'estimated_runway': '2021-12-02T09:51:00+00:00',
#     'actual_runway': '2021-12-02T09:51:00+00:00'},
#    'arrival': {'airport': 'Longnan Chengzhou Airport',
#     'timezone': None,
#     'iata': 'LNL',
#     'icao': 'ZLLN',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:25:00+00:00',
#     'estimated': '2021-12-02T11:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Shenzhen Airlines', 'iata': 'ZH', 'icao': 'CSZ'},
#    'flight': {'number': '2725',
#     'iata': 'ZH2725',
#     'icao': 'CSZ2725',
#     'codeshared': {'airline_name': 'shandong airlines',
#      'airline_iata': 'sc',
#      'airline_icao': 'cdg',
#      'flight_number': '8819',
#      'flight_iata': 'sc8819',
#      'flight_icao': 'cdg8819'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '2',
#     'gate': '13',
#     'delay': 18,
#     'scheduled': '2021-12-02T09:55:00+00:00',
#     'estimated': '2021-12-02T09:55:00+00:00',
#     'actual': '2021-12-02T09:51:00+00:00',
#     'estimated_runway': '2021-12-02T09:51:00+00:00',
#     'actual_runway': '2021-12-02T09:51:00+00:00'},
#    'arrival': {'airport': 'Longnan Chengzhou Airport',
#     'timezone': None,
#     'iata': 'LNL',
#     'icao': 'ZLLN',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T11:25:00+00:00',
#     'estimated': '2021-12-02T11:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Shandong Airlines', 'iata': 'SC', 'icao': 'CDG'},
#    'flight': {'number': '8819',
#     'iata': 'SC8819',
#     'icao': 'CDG8819',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Phuket International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'HKT',
#     'icao': 'VTSP',
#     'terminal': 'I',
#     'gate': None,
#     'delay': 19,
#     'scheduled': '2021-12-02T08:30:00+00:00',
#     'estimated': '2021-12-02T08:30:00+00:00',
# ...
#     'gate': None,
#     'baggage': None,
#     'delay': 1,
#     'scheduled': '2021-12-02T11:00:00+00:00',
#     'estimated': '2021-12-02T11:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Wings Air (Indonesia)', 'iata': 'IW', 'icao': 'WON'},
#    'flight': {'number': '1366',
#     'iata': 'IW1366',
#     'icao': 'WON1366',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Istanbul Airport',
#     'timezone': 'Europe/Istanbul',
#     'iata': 'IST',
#     'icao': 'LTFM',
#     'terminal': None,
#     'gate': 'B17',
#     'delay': 23,
#     'scheduled': '2021-12-02T01:45:00+00:00',
#     'estimated': '2021-12-02T01:45:00+00:00',
#     'actual': '2021-12-02T02:07:00+00:00',
#     'estimated_runway': '2021-12-02T02:07:00+00:00',
#     'actual_runway': '2021-12-02T02:07:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '18',
#     'delay': 11,
#     'scheduled': '2021-12-02T17:10:00+00:00',
#     'estimated': '2021-12-02T17:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'},
#    'flight': {'number': '6266',
#     'iata': 'SQ6266',
#     'icao': 'SIA6266',
#     'codeshared': {'airline_name': 'turkish airlines',
#      'airline_iata': 'tk',
#      'airline_icao': 'thy',
#      'flight_number': '54',
#      'flight_iata': 'tk54',
#      'flight_icao': 'thy54'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Istanbul Airport',
#     'timezone': 'Europe/Istanbul',
#     'iata': 'IST',
#     'icao': 'LTFM',
#     'terminal': None,
#     'gate': 'B17',
#     'delay': 23,
#     'scheduled': '2021-12-02T01:45:00+00:00',
#     'estimated': '2021-12-02T01:45:00+00:00',
#     'actual': '2021-12-02T02:07:00+00:00',
#     'estimated_runway': '2021-12-02T02:07:00+00:00',
#     'actual_runway': '2021-12-02T02:07:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '18',
#     'delay': 11,
#     'scheduled': '2021-12-02T17:10:00+00:00',
#     'estimated': '2021-12-02T17:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Royal Brunei Airlines', 'iata': 'BI', 'icao': 'RBA'},
#    'flight': {'number': '3609',
#     'iata': 'BI3609',
#     'icao': 'RBA3609',
#     'codeshared': {'airline_name': 'turkish airlines',
#      'airline_iata': 'tk',
#      'airline_icao': 'thy',
#      'flight_number': '54',
#      'flight_iata': 'tk54',
#      'flight_icao': 'thy54'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Istanbul Airport',
#     'timezone': 'Europe/Istanbul',
#     'iata': 'IST',
#     'icao': 'LTFM',
#     'terminal': None,
#     'gate': 'B18B',
#     'delay': 24,
#     'scheduled': '2021-12-02T01:35:00+00:00',
#     'estimated': '2021-12-02T01:35:00+00:00',
#     'actual': '2021-12-02T01:58:00+00:00',
#     'estimated_runway': '2021-12-02T01:58:00+00:00',
#     'actual_runway': '2021-12-02T01:58:00+00:00'},
#    'arrival': {'airport': 'Borg el Arab',
#     'timezone': 'Africa/Cairo',
#     'iata': 'HBE',
#     'icao': 'HEBA',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': 2,
#     'scheduled': '2021-12-02T02:40:00+00:00',
#     'estimated': '2021-12-02T02:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'EgyptAir', 'iata': 'MS', 'icao': 'MSR'},
#    'flight': {'number': '9296',
#     'iata': 'MS9296',
#     'icao': 'MSR9296',
#     'codeshared': {'airline_name': 'turkish airlines',
#      'airline_iata': 'tk',
#      'airline_icao': 'thy',
#      'flight_number': '696',
#      'flight_iata': 'tk696',
#      'flight_icao': 'thy696'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '3',
#     'gate': None,
#     'delay': 18,
#     'scheduled': '2021-12-02T14:55:00+00:00',
#     'estimated': '2021-12-02T14:55:00+00:00',
#     'actual': '2021-12-02T15:12:00+00:00',
#     'estimated_runway': '2021-12-02T15:12:00+00:00',
#     'actual_runway': '2021-12-02T15:12:00+00:00'},
#    'arrival': {'airport': 'Puerto Princesa',
#     'timezone': 'Asia/Manila',
#     'iata': 'PPS',
#     'icao': 'RPVP',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T16:20:00+00:00',
#     'estimated': '2021-12-02T16:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cebu Pacific Air', 'iata': '5J', 'icao': 'CEB'},
#    'flight': {'number': '647',
#     'iata': '5J647',
#     'icao': 'CEB647',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Ninoy Aquino International',
#     'timezone': 'Asia/Manila',
#     'iata': 'MNL',
#     'icao': 'RPLL',
#     'terminal': '3',
#     'gate': None,
#     'delay': 20,
#     'scheduled': '2021-12-02T14:55:00+00:00',
#     'estimated': '2021-12-02T14:55:00+00:00',
#     'actual': '2021-12-02T15:15:00+00:00',
#     'estimated_runway': '2021-12-02T15:15:00+00:00',
#     'actual_runway': '2021-12-02T15:15:00+00:00'},
#    'arrival': {'airport': 'Legazpi',
#     'timezone': 'Asia/Manila',
#     'iata': 'LGP',
#     'icao': 'RPLP',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T16:25:00+00:00',
#     'estimated': '2021-12-02T16:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cebgo', 'iata': 'DG', 'icao': 'SRQ'},
#    'flight': {'number': '6195',
#     'iata': 'DG6195',
#     'icao': 'SRQ6195',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Chitose',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'CTS',
#     'icao': 'RJCC',
#     'terminal': 'D',
#     'gate': None,
#     'delay': 11,
#     'scheduled': '2021-12-02T09:35:00+00:00',
#     'estimated': '2021-12-02T09:35:00+00:00',
#     'actual': '2021-12-02T09:46:00+00:00',
#     'estimated_runway': '2021-12-02T09:46:00+00:00',
#     'actual_runway': '2021-12-02T09:46:00+00:00'},
#    'arrival': {'airport': 'Memanbetsu',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'MMB',
#     'icao': 'RJCM',
#     'terminal': 'D',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T10:25:00+00:00',
#     'estimated': '2021-12-02T10:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '4861',
#     'iata': 'NH4861',
#     'icao': 'ANA4861',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Jinan',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'TNA',
#     'icao': 'ZSJN',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-12-02T16:10:00+00:00',
#     'estimated': '2021-12-02T16:10:00+00:00',
#     'actual': '2021-12-02T16:09:00+00:00',
#     'estimated_runway': '2021-12-02T16:09:00+00:00',
#     'actual_runway': '2021-12-02T16:09:00+00:00'},
#    'arrival': {'airport': 'Nanchang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KHN',
#     'icao': 'ZSCN',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T18:00:00+00:00',
#     'estimated': '2021-12-02T18:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Jiangxi Airlines', 'iata': 'RY', 'icao': 'CJX'},
#    'flight': {'number': '8924',
#     'iata': 'RY8924',
#     'icao': 'CJX8924',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': '21',
#     'delay': 19,
#     'scheduled': '2021-12-02T15:15:00+00:00',
#     'estimated': '2021-12-02T15:15:00+00:00',
#     'actual': '2021-12-02T15:34:00+00:00',
#     'estimated_runway': '2021-12-02T15:34:00+00:00',
#     'actual_runway': '2021-12-02T15:34:00+00:00'},
#    'arrival': {'airport': 'Guiyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'KWE',
#     'icao': 'ZUGY',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T17:50:00+00:00',
#     'estimated': '2021-12-02T17:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'},
#    'flight': {'number': '8425',
#     'iata': 'MF8425',
#     'icao': 'CXA8425',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': '5',
#     'delay': 25,
#     'scheduled': '2021-12-02T15:15:00+00:00',
#     'estimated': '2021-12-02T15:15:00+00:00',
#     'actual': '2021-12-02T15:40:00+00:00',
#     'estimated_runway': '2021-12-02T15:40:00+00:00',
#     'actual_runway': '2021-12-02T15:40:00+00:00'},
#    'arrival': {'airport': 'Tianjin Binhai International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'TSN',
#     'icao': 'ZBTJ',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T18:15:00+00:00',
#     'estimated': '2021-12-02T18:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'},
#    'flight': {'number': '8125',
#     'iata': 'MF8125',
#     'icao': 'CXA8125',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '4',
#     'gate': 'K',
#     'delay': 24,
#     'scheduled': '2021-12-02T15:05:00+00:00',
#     'estimated': '2021-12-02T15:05:00+00:00',
#     'actual': '2021-12-02T15:27:00+00:00',
#     'estimated_runway': '2021-12-02T15:27:00+00:00',
#     'actual_runway': '2021-12-02T15:27:00+00:00'},
#    'arrival': {'airport': 'Shanghai Hongqiao International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SHA',
#     'icao': 'ZSSS',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '8',
#     'delay': None,
#     'scheduled': '2021-12-02T17:05:00+00:00',
#     'estimated': '2021-12-02T17:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Spring Airlines', 'iata': '9C', 'icao': 'CQH'},
#    'flight': {'number': '8838',
#     'iata': '9C8838',
#     'icao': 'CQH8838',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': 'B',
#     'delay': 29,
#     'scheduled': '2021-12-02T15:05:00+00:00',
#     'estimated': '2021-12-02T15:05:00+00:00',
#     'actual': '2021-12-02T15:36:00+00:00',
#     'estimated_runway': '2021-12-02T15:36:00+00:00',
#     'actual_runway': '2021-12-02T15:36:00+00:00'},
#    'arrival': {'airport': 'Daguocun',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SJW',
#     'icao': 'ZBSJ',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T18:10:00+00:00',
#     'estimated': '2021-12-02T18:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Hebei Airlines', 'iata': 'NS', 'icao': 'HBH'},
#    'flight': {'number': '3262',
#     'iata': 'NS3262',
#     'icao': 'HBH3262',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': '2',
#     'delay': 9,
#     'scheduled': '2021-12-02T15:00:00+00:00',
#     'estimated': '2021-12-02T15:00:00+00:00',
#     'actual': '2021-12-02T15:08:00+00:00',
#     'estimated_runway': '2021-12-02T15:08:00+00:00',
#     'actual_runway': '2021-12-02T15:08:00+00:00'},
#    'arrival': {'airport': 'Shanghai Hongqiao International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SHA',
#     'icao': 'ZSSS',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '9',
#     'delay': None,
#     'scheduled': '2021-12-02T17:00:00+00:00',
#     'estimated': '2021-12-02T17:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'},
#    'flight': {'number': '8509',
#     'iata': 'MF8509',
#     'icao': 'CXA8509',
#     'codeshared': None},
#    'aircraft': {'registration': 'B-5499',
#     'iata': 'B738',
#     'icao': 'B738',
#     'icao24': '7805E0'},
#    'live': {'updated': '2021-12-02T08:02:05+00:00',
#     'latitude': 29.68,
#     'longitude': 120.87,
#     'altitude': 6888.48,
#     'direction': 28,
#     'speed_horizontal': 824.14,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '3',
#     'gate': '6',
#     'delay': 26,
#     'scheduled': '2021-12-02T15:00:00+00:00',
#     'estimated': '2021-12-02T15:00:00+00:00',
#     'actual': '2021-12-02T15:24:00+00:00',
#     'estimated_runway': '2021-12-02T15:24:00+00:00',
#     'actual_runway': '2021-12-02T15:24:00+00:00'},
#    'arrival': {'airport': 'Beijing Daxing International Airport',
#     'timezone': '+8',
#     'iata': 'PKX',
#     'icao': 'ZBAD',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-12-02T18:00:00+00:00',
#     'estimated': '2021-12-02T18:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'},
#    'flight': {'number': '8105',
#     'iata': 'MF8105',
#     'icao': 'CXA8105',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-12-02',
#    'flight_status': 'active',
#    'departure': {'airport': 'Xiamen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XMN',
#     'icao': 'ZSAM',
#     'terminal': '4',
#     'gate': 'K4',
#     'delay': 12,
#     'scheduled': '2021-12-02T15:00:00+00:00',
#     'estimated': '2021-12-02T15:00:00+00:00',
#     'actual': '2021-12-02T15:19:00+00:00',
#     'estimated_runway': '2021-12-02T15:19:00+00:00',
#     'actual_runway': '2021-12-02T15:19:00+00:00'},
#    'arrival': {'airport': 'Shanghai Hongqiao International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SHA',
#     'icao': 'ZSSS',
#     'terminal': '2',
#     'gate': None,
#     'baggage': '25',
#     'delay': None,
#     'scheduled': '2021-12-02T16:45:00+00:00',
#     'estimated': '2021-12-02T16:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Juneyao Airlines', 'iata': 'HO', 'icao': 'DKH'},
#    'flight': {'number': '1108',
#     'iata': 'HO1108',
#     'icao': 'DKH1108',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None}]}

# %% [markdown]
# ## Ответ на вопрос: 15658

# %%
planes['pagination']['total'] # выводим общее число результатов для нашего api
# Out:
# 15658

# %%
flights = pd.json_normalize(planes['data'])

# %%
flights
# Out:
#    flight_date flight_status  aircraft  live  \
# 0   2021-12-02        active       NaN   NaN
# 1   2021-12-02        active       NaN   NaN
# 2   2021-12-02        active       NaN   NaN
# 3   2021-12-02        active       NaN   NaN
# 4   2021-12-02        active       NaN   NaN
# ..         ...           ...       ...   ...
# 95  2021-12-02        active       NaN   NaN
# 96  2021-12-02        active       NaN   NaN
# 97  2021-12-02        active       NaN   NaN
# 98  2021-12-02        active       NaN   NaN
# 99  2021-12-02        active       NaN   NaN
#
#                                     departure.airport   departure.timezone  \
# 0                               Baghdad International         Asia/Baghdad
# 1                                            Heathrow        Europe/London
# 2                                            Srinagar         Asia/Kolkata
# 3   Oliver Reginald Tambo International (Jan Smuts...  Africa/Johannesburg
# 4                                       Luton Airport        Europe/London
# ..                                                ...                  ...
# 95                                             Xiamen        Asia/Shanghai
# 96                                             Xiamen        Asia/Shanghai
# 97                                             Xiamen        Asia/Shanghai
# 98                                             Xiamen        Asia/Shanghai
# 99                                             Xiamen        Asia/Shanghai
#
#    departure.iata departure.icao departure.terminal departure.gate  ...  \
# 0             BGW           ORBI               None           None  ...
# 1             LHR           EGLL                  5            C62  ...
# 2             SXR           VISR               None           None  ...
# 3             JNB           FAOR                  B             D3  ...
# 4             LTN           EGGW               None           None  ...
# ..            ...            ...                ...            ...  ...
# 95            XMN           ZSAM                  4              K  ...
# 96            XMN           ZSAM                  3              B  ...
# 97            XMN           ZSAM                  3              2  ...
# 98            XMN           ZSAM                  3              6  ...
# 99            XMN           ZSAM                  4             K4  ...
#
#     aircraft.icao aircraft.icao24               live.updated live.latitude  \
# 0             NaN             NaN                        NaN           NaN
# 1             NaN             NaN                        NaN           NaN
# 2             NaN             NaN                        NaN           NaN
# 3             NaN             NaN                        NaN           NaN
# 4             NaN             NaN                        NaN           NaN
# ..            ...             ...                        ...           ...
# 95            NaN             NaN                        NaN           NaN
# 96            NaN             NaN                        NaN           NaN
# 97           B738          7805E0  2021-12-02T08:02:05+00:00         29.68
# 98            NaN             NaN                        NaN           NaN
# 99            NaN             NaN                        NaN           NaN
#
#    live.longitude live.altitude live.direction live.speed_horizontal  \
# 0             NaN           NaN            NaN                   NaN
# 1             NaN           NaN            NaN                   NaN
# 2             NaN           NaN            NaN                   NaN
# 3             NaN           NaN            NaN                   NaN
# 4             NaN           NaN            NaN                   NaN
# ..            ...           ...            ...                   ...
# 95            NaN           NaN            NaN                   NaN
# 96            NaN           NaN            NaN                   NaN
# 97         120.87       6888.48           28.0                824.14
# 98            NaN           NaN            NaN                   NaN
# 99            NaN           NaN            NaN                   NaN
#
#    live.speed_vertical live.is_ground
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# ..                 ...            ...
# 95                 NaN            NaN
# 96                 NaN            NaN
# 97                 0.0          False
# 98                 NaN            NaN
# 99                 NaN            NaN
#
# [100 rows x 54 columns]
