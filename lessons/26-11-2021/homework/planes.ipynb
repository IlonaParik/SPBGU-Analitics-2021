# %% [markdown]
# Найдите список всех самолетов, находящихся сейчас в воздухе. (Имеется в виду на момент выполнения домашки)
#
# Возможно вам поможет это: https://aviationstack.com/documentation

# %%
api_key = '24c727da9ec7cade153b70380850cf92'

# %%
import requests

params = {
  'access_key': api_key
}

api_result = requests.get('http://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

for flight in api_response['results']:
    if (flight['live']['is_ground'] is False):
        print(u'%s flight %s from %s (%s) to %s (%s) is in the air.' % (
            flight['airline']['name'],
            flight['flight']['iata'],
            flight['departure']['airport'],
            flight['departure']['iata'],
            flight['arrival']['airport'],
            flight['arrival']['iata']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-75de6e1a93cc> in <module>
#       9 api_response = api_result.json()
#      10
# ---> 11 for flight in api_response['results']:
#      12     if (flight['live']['is_ground'] is False):
#      13         print(u'%s flight %s from %s (%s) to %s (%s) is in the air.' % (
#
# KeyError: 'results'

# %%
api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 299075},
#  'data': [{'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Armidale',
#     'timezone': 'Australia/Sydney',
#     'iata': 'ARM',
#     'icao': 'YARM',
#     'terminal': None,
#     'gate': None,
#     'delay': 15,
#     'scheduled': '2021-11-27T06:30:00+00:00',
#     'estimated': '2021-11-27T06:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:50:00+00:00',
#     'estimated': '2021-11-27T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'},
#    'flight': {'number': '5154',
#     'iata': 'EK5154',
#     'icao': 'UAE5154',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '2019',
#      'flight_iata': 'qf2019',
#      'flight_icao': 'qfa2019'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Armidale',
#     'timezone': 'Australia/Sydney',
#     'iata': 'ARM',
#     'icao': 'YARM',
#     'terminal': None,
#     'gate': None,
#     'delay': 15,
#     'scheduled': '2021-11-27T06:30:00+00:00',
#     'estimated': '2021-11-27T06:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:50:00+00:00',
#     'estimated': '2021-11-27T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'},
#    'flight': {'number': '4184',
#     'iata': 'MU4184',
#     'icao': 'CES4184',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '2019',
#      'flight_iata': 'qf2019',
#      'flight_icao': 'qfa2019'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Armidale',
#     'timezone': 'Australia/Sydney',
#     'iata': 'ARM',
#     'icao': 'YARM',
#     'terminal': None,
#     'gate': None,
#     'delay': 15,
#     'scheduled': '2021-11-27T06:30:00+00:00',
#     'estimated': '2021-11-27T06:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:50:00+00:00',
#     'estimated': '2021-11-27T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'},
#    'flight': {'number': '7015',
#     'iata': 'NZ7015',
#     'icao': 'ANZ7015',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '2019',
#      'flight_iata': 'qf2019',
#      'flight_icao': 'qfa2019'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Armidale',
#     'timezone': 'Australia/Sydney',
#     'iata': 'ARM',
#     'icao': 'YARM',
#     'terminal': None,
#     'gate': None,
#     'delay': 15,
#     'scheduled': '2021-11-27T06:30:00+00:00',
#     'estimated': '2021-11-27T06:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:50:00+00:00',
#     'estimated': '2021-11-27T07:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'},
#    'flight': {'number': '2019',
#     'iata': 'QF2019',
#     'icao': 'QFA2019',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Sanganeer',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'JAI',
#     'icao': 'VIJP',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Goa International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'GOI',
#     'icao': 'VOGO',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T02:55:00+00:00',
#     'estimated': '2021-11-27T02:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'},
#    'flight': {'number': '768',
#     'iata': '6E768',
#     'icao': 'IGO768',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Canberra',
#     'timezone': 'Australia/Sydney',
#     'iata': 'CBR',
#     'icao': 'YSCB',
#     'terminal': None,
#     'gate': '14',
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:55:00+00:00',
#     'estimated': '2021-11-27T07:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'},
#    'flight': {'number': '5269',
#     'iata': 'EK5269',
#     'icao': 'UAE5269',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '1422',
#      'flight_iata': 'qf1422',
#      'flight_icao': 'qfa1422'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Canberra',
#     'timezone': 'Australia/Sydney',
#     'iata': 'CBR',
#     'icao': 'YSCB',
#     'terminal': None,
#     'gate': '14',
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:55:00+00:00',
#     'estimated': '2021-11-27T07:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Jetstar', 'iata': 'JQ', 'icao': 'JST'},
#    'flight': {'number': '6422',
#     'iata': 'JQ6422',
#     'icao': 'JST6422',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '1422',
#      'flight_iata': 'qf1422',
#      'flight_icao': 'qfa1422'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Canberra',
#     'timezone': 'Australia/Sydney',
#     'iata': 'CBR',
#     'icao': 'YSCB',
#     'terminal': None,
#     'gate': '14',
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '3',
#     'gate': 'T3G',
#     'baggage': 'QFR',
#     'delay': None,
#     'scheduled': '2021-11-27T07:55:00+00:00',
#     'estimated': '2021-11-27T07:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'},
#    'flight': {'number': '7318',
#     'iata': 'NZ7318',
#     'icao': 'ANZ7318',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '1422',
#      'flight_iata': 'qf1422',
#      'flight_icao': 'qfa1422'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Chongqing Jiangbei International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'CKG',
#     'icao': 'ZUCK',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T03:00:00+00:00',
#     'estimated': '2021-11-27T03:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Shanghai Pudong International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PVG',
#     'icao': 'ZSPD',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T05:20:00+00:00',
#     'estimated': '2021-11-27T05:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'},
#    'flight': {'number': '496',
#     'iata': 'CZ496',
#     'icao': 'CSN496',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Chongqing Jiangbei International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'CKG',
#     'icao': 'ZUCK',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T02:30:00+00:00',
#     'estimated': '2021-11-27T02:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Shuangliu',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'CTU',
#     'icao': 'ZUUU',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T03:45:00+00:00',
#     'estimated': '2021-11-27T03:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '3261',
#     'iata': 'CX3261',
#     'icao': 'CPA3261',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hokitika Airport',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'HKK',
#     'icao': 'NZHK',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T09:45:00+00:00',
#     'estimated': '2021-11-27T09:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Christchurch International',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'CHC',
#     'icao': 'NZCH',
#     'terminal': None,
#     'gate': 'D11',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T10:25:00+00:00',
#     'estimated': '2021-11-27T10:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'},
#    'flight': {'number': '4505',
#     'iata': 'SQ4505',
#     'icao': 'SIA4505',
#     'codeshared': {'airline_name': 'air new zealand',
#      'airline_iata': 'nz',
#      'airline_icao': 'anz',
#      'flight_number': '8831',
#      'flight_iata': 'nz8831',
#      'flight_icao': 'anz8831'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': '3',
#     'gate': 'G',
#     'delay': None,
#     'scheduled': '2021-11-27T04:35:00+00:00',
#     'estimated': '2021-11-27T04:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:45:00+00:00',
#     'estimated': '2021-11-27T08:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Korean Air', 'iata': 'KE', 'icao': 'KAL'},
#    'flight': {'number': '324',
#     'iata': 'KE324',
#     'icao': 'KAL324',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Launceston',
#     'timezone': 'Australia/Hobart',
#     'iata': 'LST',
#     'icao': 'YMLT',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T04:15:00+00:00',
#     'estimated': '2021-11-27T04:15:00+00:00',
#     'actual': '2021-11-27T03:32:00+00:00',
#     'estimated_runway': '2021-11-27T03:32:00+00:00',
#     'actual_runway': '2021-11-27T03:32:00+00:00'},
#    'arrival': {'airport': 'Hobart',
#     'timezone': 'Australia/Hobart',
#     'iata': 'HBA',
#     'icao': 'YMHB',
#     'terminal': 'D',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T04:45:00+00:00',
#     'estimated': '2021-11-27T04:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'},
#    'flight': {'number': '7367',
#     'iata': 'QF7367',
#     'icao': 'QFA7367',
#     'codeshared': None},
#    'aircraft': {'registration': 'VH-XMR',
#     'iata': 'B733',
#     'icao': 'B733',
#     'icao24': '7C7631'},
#    'live': {'updated': '2021-11-26T16:53:46+00:00',
#     'latitude': -42.55,
#     'longitude': 147.43,
#     'altitude': 1188.72,
#     'direction': 303.02,
#     'speed_horizontal': 353.412,
#     'speed_vertical': -22.248,
#     'is_ground': False}},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:55:00+00:00',
#     'estimated': '2021-11-27T00:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kuala Lumpur International Airport (klia)',
#     'timezone': 'Asia/Kuala_Lumpur',
#     'iata': 'KUL',
#     'icao': 'WMKK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T05:15:00+00:00',
#     'estimated': '2021-11-27T05:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '6053',
#     'iata': 'MH6053',
#     'icao': 'MAS6053',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': '7',
#     'delay': None,
#     'scheduled': '2021-11-27T04:45:00+00:00',
#     'estimated': '2021-11-27T04:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'},
#    'flight': {'number': '977',
#     'iata': 'QR977',
#     'icao': 'QTR977',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': '7',
#     'delay': None,
#     'scheduled': '2021-11-27T04:45:00+00:00',
#     'estimated': '2021-11-27T04:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'S7 Airlines', 'iata': 'S7', 'icao': 'SBI'},
#    'flight': {'number': '4746',
#     'iata': 'S74746',
#     'icao': 'SBI4746',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '977',
#      'flight_iata': 'qr977',
#      'flight_icao': 'qtr977'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': '7',
#     'delay': None,
#     'scheduled': '2021-11-27T04:45:00+00:00',
#     'estimated': '2021-11-27T04:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'LATAM Airlines', 'iata': 'LA', 'icao': 'LAN'},
#    'flight': {'number': '5276',
#     'iata': 'LA5276',
#     'icao': 'LAN5276',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '977',
#      'flight_iata': 'qr977',
#      'flight_icao': 'qtr977'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': '7',
#     'delay': None,
#     'scheduled': '2021-11-27T04:45:00+00:00',
#     'estimated': '2021-11-27T04:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'},
#    'flight': {'number': '2349',
#     'iata': 'IB2349',
#     'icao': 'IBE2349',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '977',
#      'flight_iata': 'qr977',
#      'flight_icao': 'qtr977'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Doha International',
#     'timezone': 'Asia/Qatar',
#     'iata': 'DOH',
#     'icao': 'OTHH',
#     'terminal': None,
#     'gate': None,
#     'baggage': '7',
#     'delay': None,
#     'scheduled': '2021-11-27T04:45:00+00:00',
#     'estimated': '2021-11-27T04:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'},
#    'flight': {'number': '4491',
#     'iata': 'BA4491',
#     'icao': 'BAW4491',
#     'codeshared': {'airline_name': 'qatar airways',
#      'airline_iata': 'qr',
#      'airline_icao': 'qtr',
#      'flight_number': '977',
#      'flight_iata': 'qr977',
#      'flight_icao': 'qtr977'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:25:00+00:00',
#     'estimated': '2021-11-27T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '1',
#     'gate': '44',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '898',
#     'iata': 'NH898',
#     'icao': 'ANA898',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:25:00+00:00',
#     'estimated': '2021-11-27T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '1',
#     'gate': '44',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vietnam Airlines', 'iata': 'VN', 'icao': 'HVN'},
#    'flight': {'number': '3498',
#     'iata': 'VN3498',
#     'icao': 'HVN3498',
#     'codeshared': {'airline_name': 'ana',
#      'airline_iata': 'nh',
#      'airline_icao': 'ana',
#      'flight_number': '898',
#      'flight_iata': 'nh898',
#      'flight_icao': 'ana898'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:25:00+00:00',
#     'estimated': '2021-11-27T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '1',
#     'gate': '44',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'United Airlines', 'iata': 'UA', 'icao': 'UAL'},
#    'flight': {'number': '7921',
#     'iata': 'UA7921',
#     'icao': 'UAL7921',
#     'codeshared': {'airline_name': 'ana',
#      'airline_iata': 'nh',
#      'airline_icao': 'ana',
#      'flight_number': '898',
#      'flight_iata': 'nh898',
#      'flight_icao': 'ana898'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': 'T3',
#     'gate': None,
#     'delay': 21,
#     'scheduled': '2021-11-27T00:10:00+00:00',
#     'estimated': '2021-11-27T00:10:00+00:00',
#     'actual': '2021-11-27T00:31:00+00:00',
#     'estimated_runway': '2021-11-27T00:31:00+00:00',
#     'actual_runway': '2021-11-27T00:31:00+00:00'},
#    'arrival': {'airport': 'Haikou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'HAK',
#     'icao': 'ZJHK',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T01:25:00+00:00',
#     'estimated': '2021-11-27T01:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'},
#    'flight': {'number': '9925',
#     'iata': 'CZ9925',
#     'icao': 'CSN9925',
#     'codeshared': {'airline_name': 'donghai airlines',
#      'airline_iata': 'dz',
#      'airline_icao': 'epa',
#      'flight_number': '6259',
#      'flight_iata': 'dz6259',
#      'flight_icao': 'epa6259'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T02:05:00+00:00',
#     'estimated': '2021-11-27T02:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Daegu',
#     'timezone': 'Asia/Seoul',
#     'iata': 'TAE',
#     'icao': 'RKTN',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T05:35:00+00:00',
#     'estimated': '2021-11-27T05:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Busan', 'iata': 'BX', 'icao': 'ABL'},
#    'flight': {'number': '792',
#     'iata': 'BX792',
#     'icao': 'ABL792',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': None,
#     'gate': '509',
#     'delay': 140,
#     'scheduled': '2021-11-27T01:40:00+00:00',
#     'estimated': '2021-11-27T01:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': None,
#     'timezone': None,
#     'iata': 'DWC',
#     'icao': 'OMDW',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T06:40:00+00:00',
#     'estimated': '2021-11-27T06:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Airlines', 'iata': 'CI', 'icao': 'CAL'},
#    'flight': {'number': '5555',
#     'iata': 'CI5555',
#     'icao': 'CAL5555',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T01:35:00+00:00',
#     'estimated': '2021-11-27T01:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chhatrapati Shivaji International (Sahar International)',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'BOM',
#     'icao': 'VABB',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T06:10:00+00:00',
#     'estimated': '2021-11-27T06:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Airlines', 'iata': 'CI', 'icao': 'CAL'},
#    'flight': {'number': '5685',
#     'iata': 'CI5685',
#     'icao': 'CAL5685',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hamilton',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'HLZ',
#     'icao': 'NZHN',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Wellington International',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'WLG',
#     'icao': 'NZWN',
#     'terminal': None,
#     'gate': '18',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:15:00+00:00',
#     'estimated': '2021-11-27T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'},
#    'flight': {'number': '5821',
#     'iata': 'NZ5821',
#     'icao': 'ANZ5821',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hamilton',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'HLZ',
#     'icao': 'NZHN',
#     'terminal': None,
#     'gate': None,
#     'delay': 4,
#     'scheduled': '2021-11-27T06:15:00+00:00',
#     'estimated': '2021-11-27T06:15:00+00:00',
#     'actual': '2021-11-27T06:19:00+00:00',
#     'estimated_runway': '2021-11-27T06:19:00+00:00',
#     'actual_runway': '2021-11-27T06:19:00+00:00'},
#    'arrival': {'airport': 'Christchurch International',
#     'timezone': 'Pacific/Auckland',
#     'iata': 'CHC',
#     'icao': 'NZCH',
#     'terminal': None,
#     'gate': 'D15',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:05:00+00:00',
#     'estimated': '2021-11-27T08:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'},
#    'flight': {'number': '5629',
#     'iata': 'NZ5629',
#     'icao': 'ANZ5629',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Phuket International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'HKT',
#     'icao': 'VTSP',
#     'terminal': 'I',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T00:20:00+00:00',
#     'estimated': '2021-11-27T00:20:00+00:00',
#     'actual': '2021-11-27T00:20:00+00:00',
#     'estimated_runway': '2021-11-27T00:20:00+00:00',
#     'actual_runway': '2021-11-27T00:20:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T06:20:00+00:00',
#     'estimated': '2021-11-27T06:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Thai Airways International',
#     'iata': 'TG',
#     'icao': 'THA'},
#    'flight': {'number': '918',
#     'iata': 'TG918',
#     'icao': 'THA918',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Phuket International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'HKT',
#     'icao': 'VTSP',
#     'terminal': '1',
#     'gate': None,
#     'delay': 7,
#     'scheduled': '2021-11-27T00:10:00+00:00',
#     'estimated': '2021-11-27T00:10:00+00:00',
#     'actual': '2021-11-27T00:17:00+00:00',
#     'estimated_runway': '2021-11-27T00:17:00+00:00',
#     'actual_runway': '2021-11-27T00:17:00+00:00'},
#    'arrival': {'airport': 'Dubai',
#     'timezone': 'Asia/Dubai',
#     'iata': 'DXB',
#     'icao': 'OMDB',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T03:45:00+00:00',
#     'estimated': '2021-11-27T03:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'},
#    'flight': {'number': '379',
#     'iata': 'EK379',
#     'icao': 'UAE379',
#     'codeshared': None},
#    'aircraft': {'registration': 'A6-EPN',
#     'iata': 'B77W',
#     'icao': 'B77W',
#     'icao24': '8963DD'},
#    'live': {'updated': '2021-11-26T17:00:57+00:00',
#     'latitude': 8.11,
#     'longitude': 98.3,
#     'altitude': 0,
#     'direction': 14,
#     'speed_horizontal': 1.852,
#     'speed_vertical': 0,
#     'is_ground': True}},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Phuket International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'HKT',
#     'icao': 'VTSP',
#     'terminal': '1',
#     'gate': None,
#     'delay': 7,
#     'scheduled': '2021-11-27T00:10:00+00:00',
#     'estimated': '2021-11-27T00:10:00+00:00',
#     'actual': '2021-11-27T00:17:00+00:00',
#     'estimated_runway': '2021-11-27T00:17:00+00:00',
#     'actual_runway': '2021-11-27T00:17:00+00:00'},
#    'arrival': {'airport': 'Dubai',
#     'timezone': 'Asia/Dubai',
#     'iata': 'DXB',
#     'icao': 'OMDB',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T03:45:00+00:00',
#     'estimated': '2021-11-27T03:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Thai Airways International',
#     'iata': 'TG',
#     'icao': 'THA'},
#    'flight': {'number': '4505',
#     'iata': 'TG4505',
#     'icao': 'THA4505',
#     'codeshared': {'airline_name': 'emirates',
#      'airline_iata': 'ek',
#      'airline_icao': 'uae',
#      'flight_number': '379',
#      'flight_iata': 'ek379',
#      'flight_icao': 'uae379'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Xianyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XIY',
#     'icao': 'ZLXY',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T02:00:00+00:00',
#     'estimated': '2021-11-27T02:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Xuzhou',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'XUZ',
#     'icao': 'ZSXZ',
#     'terminal': 'T2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T03:45:00+00:00',
#     'estimated': '2021-11-27T03:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Longhao Airlines', 'iata': 'GI', 'icao': 'LHA'},
#    'flight': {'number': '4017',
#     'iata': 'GI4017',
#     'icao': 'LHA4017',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T01:45:00+00:00',
#     'estimated': '2021-11-27T01:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ted Stevens Anchorage International Airport',
#     'timezone': 'America/Anchorage',
#     'iata': 'ANC',
#     'icao': 'PANC',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-26T18:15:00+00:00',
#     'estimated': '2021-11-26T18:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '86',
#     'iata': 'CX86',
#     'icao': 'CPA86',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'active',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': '1',
#     'gate': 'B',
#     'delay': 1,
#     'scheduled': '2021-11-27T01:30:00+00:00',
#     'estimated': '2021-11-27T01:30:00+00:00',
#     'actual': '2021-11-27T01:30:00+00:00',
#     'estimated_runway': '2021-11-27T01:30:00+00:00',
#     'actual_runway': '2021-11-27T01:30:00+00:00'},
#    'arrival': {'airport': 'Ben Gurion International',
#     'timezone': 'Asia/Jerusalem',
#     'iata': 'TLV',
#     'icao': 'LLBG',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T07:15:00+00:00',
#     'estimated': '2021-11-27T07:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '675',
#     'iata': 'CX675',
#     'icao': 'CPA675',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T01:20:00+00:00',
#     'estimated': '2021-11-27T01:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T05:55:00+00:00',
#     'estimated': '2021-11-27T05:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Polar Air Cargo', 'iata': 'PO', 'icao': 'PAC'},
#    'flight': {'number': '96',
#     'iata': 'PO96',
#     'icao': 'PAC96',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Hong Kong International',
#     'timezone': 'Asia/Hong_Kong',
#     'iata': 'HKG',
#     'icao': 'VHHH',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T01:15:00+00:00',
#     'estimated': '2021-11-27T01:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Narita International Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'NRT',
#     'icao': 'RJAA',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T06:15:00+00:00',
#     'estimated': '2021-11-27T06:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'},
#    'flight': {'number': '6',
#     'iata': 'CX6',
#     'icao': 'CPA6',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Ballina Byron Gateway',
#     'timezone': 'Australia/Sydney',
#     'iata': 'BNK',
#     'icao': 'YBNA',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:05:00+00:00',
#     'estimated': '2021-11-27T08:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '2',
#     'gate': 'A52',
#     'baggage': 'D4',
#     'delay': None,
#     'scheduled': '2021-11-27T09:25:00+00:00',
#     'estimated': '2021-11-27T09:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Jetstar', 'iata': 'JQ', 'icao': 'JST'},
#    'flight': {'number': '457',
#     'iata': 'JQ457',
#     'icao': 'JST457',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Ballina Byron Gateway',
#     'timezone': 'Australia/Sydney',
#     'iata': 'BNK',
#     'icao': 'YBNA',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:05:00+00:00',
#     'estimated': '2021-11-27T08:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '2',
#     'gate': 'A52',
#     'baggage': 'D4',
#     'delay': None,
#     'scheduled': '2021-11-27T09:25:00+00:00',
#     'estimated': '2021-11-27T09:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'},
#    'flight': {'number': '7511',
#     'iata': 'EK7511',
#     'icao': 'UAE7511',
#     'codeshared': {'airline_name': 'jetstar',
#      'airline_iata': 'jq',
#      'airline_icao': 'jst',
#      'flight_number': '457',
#      'flight_iata': 'jq457',
#      'flight_icao': 'jst457'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Ballina Byron Gateway',
#     'timezone': 'Australia/Sydney',
#     'iata': 'BNK',
#     'icao': 'YBNA',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:05:00+00:00',
#     'estimated': '2021-11-27T08:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kingsford Smith',
#     'timezone': 'Australia/Sydney',
#     'iata': 'SYD',
#     'icao': 'YSSY',
#     'terminal': '2',
#     'gate': 'A52',
#     'baggage': 'D4',
#     'delay': None,
#     'scheduled': '2021-11-27T09:25:00+00:00',
#     'estimated': '2021-11-27T09:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'},
#    'flight': {'number': '5457',
#     'iata': 'QF5457',
#     'icao': 'QFA5457',
#     'codeshared': {'airline_name': 'jetstar',
#      'airline_iata': 'jq',
#      'airline_icao': 'jst',
#      'flight_number': '457',
#      'flight_iata': 'jq457',
#      'flight_icao': 'jst457'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Brisbane International',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'BNE',
#     'icao': 'YBBN',
#     'terminal': 'D',
#     'gate': '43',
#     'delay': None,
#     'scheduled': '2021-11-27T07:05:00+00:00',
#     'estimated': '2021-11-27T07:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Whitsunday Coast',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'PPP',
#     'icao': 'YBPN',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:45:00+00:00',
#     'estimated': '2021-11-27T08:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Virgin Australia', 'iata': 'VA', 'icao': 'VOZ'},
#    'flight': {'number': '1113',
#     'iata': 'VA1113',
#     'icao': 'VOZ1113',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Brisbane International',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'BNE',
#     'icao': 'YBBN',
#     'terminal': 'D',
#     'gate': '43',
#     'delay': None,
#     'scheduled': '2021-11-27T07:05:00+00:00',
#     'estimated': '2021-11-27T07:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Whitsunday Coast',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'PPP',
#     'icao': 'YBPN',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:45:00+00:00',
#     'estimated': '2021-11-27T08:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'},
#    'flight': {'number': '6508',
#     'iata': 'SQ6508',
#     'icao': 'SIA6508',
#     'codeshared': {'airline_name': 'virgin australia',
#      'airline_iata': 'va',
#      'airline_icao': 'voz',
#      'flight_number': '1113',
#      'flight_iata': 'va1113',
#      'flight_icao': 'voz1113'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Brisbane International',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'BNE',
#     'icao': 'YBBN',
#     'terminal': 'D',
#     'gate': '43',
#     'delay': None,
#     'scheduled': '2021-11-27T07:05:00+00:00',
#     'estimated': '2021-11-27T07:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Whitsunday Coast',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'PPP',
#     'icao': 'YBPN',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:45:00+00:00',
#     'estimated': '2021-11-27T08:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Etihad Airways', 'iata': 'EY', 'icao': 'ETD'},
#    'flight': {'number': '6409',
#     'iata': 'EY6409',
#     'icao': 'ETD6409',
#     'codeshared': {'airline_name': 'virgin australia',
#      'airline_iata': 'va',
#      'airline_icao': 'voz',
#      'flight_number': '1113',
#      'flight_iata': 'va1113',
#      'flight_icao': 'voz1113'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Brisbane International',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'BNE',
#     'icao': 'YBBN',
#     'terminal': 'I',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T07:00:00+00:00',
#     'estimated': '2021-11-27T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Bonriki',
#     'timezone': 'Pacific/Tarawa',
#     'iata': 'TRW',
#     'icao': 'NGTA',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T14:00:00+00:00',
#     'estimated': '2021-11-27T14:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Solomon Airlines', 'iata': 'IE', 'icao': 'SOL'},
#    'flight': {'number': '616',
#     'iata': 'IE616',
#     'icao': 'SOL616',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Brisbane International',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'BNE',
#     'icao': 'YBBN',
#     'terminal': 'D',
#     'gate': '1',
#     'delay': None,
#     'scheduled': '2021-11-27T06:45:00+00:00',
#     'estimated': '2021-11-27T06:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Emerald',
#     'timezone': 'Australia/Brisbane',
#     'iata': 'EMD',
#     'icao': 'YEML',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T08:20:00+00:00',
# ...
#    'flight': {'number': '7936',
#     'iata': 'Y87936',
#     'icao': 'YZR7936',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Taiwan Taoyuan International (Chiang Kai Shek International)',
#     'timezone': 'Asia/Taipei',
#     'iata': 'TPE',
#     'icao': 'RCTP',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T04:55:00+00:00',
#     'estimated': '2021-11-27T04:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': 'T3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T06:55:00+00:00',
#     'estimated': '2021-11-27T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SF Airlines', 'iata': 'O3', 'icao': 'CSS'},
#    'flight': {'number': '6918',
#     'iata': 'O36918',
#     'icao': 'CSS6918',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Oman Air', 'iata': 'WY', 'icao': 'OMA'},
#    'flight': {'number': '5460',
#     'iata': 'WY5460',
#     'icao': 'OMA5460',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Europa', 'iata': 'UX', 'icao': 'AEA'},
#    'flight': {'number': '2705',
#     'iata': 'UX2705',
#     'icao': 'AEA2705',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Saudia', 'iata': 'SV', 'icao': 'SVA'},
#    'flight': {'number': '6994',
#     'iata': 'SV6994',
#     'icao': 'SVA6994',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Pakistan International Airlines',
#     'iata': 'PK',
#     'icao': 'PIA'},
#    'flight': {'number': '4460',
#     'iata': 'PK4460',
#     'icao': 'PIA4460',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'},
#    'flight': {'number': '4260',
#     'iata': 'NZ4260',
#     'icao': 'ANZ4260',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'EgyptAir', 'iata': 'MS', 'icao': 'MSR'},
#    'flight': {'number': '8078',
#     'iata': 'MS8078',
#     'icao': 'MSR8078',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Middle East Airlines', 'iata': 'ME', 'icao': 'MEA'},
#    'flight': {'number': '6638',
#     'iata': 'ME6638',
#     'icao': 'MEA6638',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'},
#    'flight': {'number': '9628',
#     'iata': 'LY9628',
#     'icao': 'ELY9628',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Malta', 'iata': 'KM', 'icao': 'AMC'},
#    'flight': {'number': '2157',
#     'iata': 'KM2157',
#     'icao': 'AMC2157',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'},
#    'flight': {'number': '3940',
#     'iata': 'KL3940',
#     'icao': 'KLM3940',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'},
#    'flight': {'number': '7558',
#     'iata': 'JU7558',
#     'icao': 'ASL7558',
#     'codeshared': {'airline_name': 'etihad airways',
#      'airline_iata': 'ey',
#      'airline_icao': 'etd',
#      'flight_number': '460',
#      'flight_iata': 'ey460',
#      'flight_icao': 'etd460'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '3',
#     'gate': '58',
#     'delay': 16,
#     'scheduled': '2021-11-27T00:40:00+00:00',
#     'estimated': '2021-11-27T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tullamarine',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': '4',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T21:05:00+00:00',
#     'estimated': '2021-11-27T21:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Etihad Airways', 'iata': 'EY', 'icao': 'ETD'},
#    'flight': {'number': '460',
#     'iata': 'EY460',
#     'icao': 'ETD460',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2021-11-27',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abu Dhabi International',
#     'timezone': 'Asia/Dubai',
#     'iata': 'AUH',
#     'icao': 'OMAA',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2021-11-27T01:00:00+00:00',
#     'estimated': '2021-11-27T01:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Damascus International Airport',
#     'timezone': 'Asia/Damascus',
#     'iata': 'DAM',
#     'icao': 'OSDI',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2021-11-27T02:15:00+00:00',
#     'estimated': '2021-11-27T02:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cham Wings Airlines', 'iata': '6Q', 'icao': 'SAW'},
#    'flight': {'number': '732',
#     'iata': '6Q732',
#     'icao': 'SAW732',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None}]}
