# %%
import pandas as pd

# %%
data = pd.read_csv('heart.csv')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
desc = data.describe()

# %%
desc.to_excel('heart_lesson_titova.xlsx')

# %%
df.loc[(df.sex == 'M') & (df.	HeartDisease == ('1'))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/431931929.py in <module>
# ----> 1 df.loc[(df.sex == 'M') & (df.   HeartDisease == ('1'))]
#
# NameError: name 'df' is not defined

# %%
data.loc[df.Sex == 'M']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/2260436524.py in <module>
# ----> 1 data.loc[df.Sex == 'M']
#
# NameError: name 'df' is not defined

# %%
data.loc[data.Sex == 'M']
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 4     54   M           NAP        150          195          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# 7     54   M           ATA        110          208          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 911   59   M           ASY        164          176          1        LVH
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.loc[data.Sex == 'M']  & data.loc[data.HeartDisease == '1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/3948847875.py in <module>
# ----> 1 data.loc[data.Sex == 'M']  & data.loc[data.HeartDisease == '1']
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...

# %%
data[data.Sex == 'M']  & data[data.HeartDisease == '1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/2401177153.py in <module>
# ----> 1 data[data.Sex == 'M']  & data[data.HeartDisease == '1']
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...

# %%
data[(data['Sex'] == 'M')  & (data['HeartDisease'] == 1)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 8     37   M           ASY        140          207          0     Normal
# 11    58   M           ATA        136          164          0         ST
# 13    49   M           ASY        140          234          0     Normal
# 16    38   M           ASY        110          196          0     Normal
# 18    60   M           ASY        100          248          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 908   63   M           ASY        140          187          0        LVH
# 911   59   M           ASY        164          176          1        LVH
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data[(data['Sex'] == 'F')  & (data['HeartDisease'] == 1)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 41    54   F           NAP        130          294          0         ST
# 51    47   F           ASY        120          205          0     Normal
# 102   40   F           ASY        150          392          0     Normal
# 115   33   F           ASY        100          246          0     Normal
# 117   59   F           ASY        130          338          1         ST
# 120   47   F           NAP        135          248          1     Normal
# 123   58   F           ATA        180          393          0     Normal
# 144   56   F           ATA        120          279          0     Normal
# 211   50   F           NAP        140          288          0     Normal
# 221   51   F           ASY        160          303          0     Normal
# ...

# %%
count(data[(data['Sex'] == 'M')  & (data['HeartDisease'] == 1)] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/1268812683.py in <module>
# ----> 1 count(data[(data['Sex'] == 'M')  & (data['HeartDisease'] == 1)] )
#
# NameError: name 'count' is not defined

# %%
data[(data['Sex'] == 'F')  & (data['HeartDisease'] == 1)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 41    54   F           NAP        130          294          0         ST
# 51    47   F           ASY        120          205          0     Normal
# 102   40   F           ASY        150          392          0     Normal
# 115   33   F           ASY        100          246          0     Normal
# 117   59   F           ASY        130          338          1         ST
# 120   47   F           NAP        135          248          1     Normal
# 123   58   F           ATA        180          393          0     Normal
# 144   56   F           ATA        120          279          0     Normal
# 211   50   F           NAP        140          288          0     Normal
# 221   51   F           ASY        160          303          0     Normal
# ...

# %%
female = data[(data['Sex'] == 'F')  & (data['HeartDisease'] == 1)]

# %%
female.to_excel('female.[xlsx]')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     826                 try:
# --> 827                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#     828                     if engine == "auto":
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     242     def __call__(self, *args, **kwds):
# --> 243         return self.__func__(*args, **kwds)
#     244
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in _get_option(pat, silent)
#     114 def _get_option(pat: str, silent: bool = False):
# --> 115     key = _get_single_key(pat, silent)
#     116
#
# ...

# %%
female.to_excel('female.xlsx')

# %%
female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 916
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             50 non-null     int64
#  1   Sex             50 non-null     object
#  2   ChestPainType   50 non-null     object
#  3   RestingBP       50 non-null     int64
#  4   Cholesterol     50 non-null     int64
#  5   FastingBS       50 non-null     int64
#  6   RestingECG      50 non-null     object
#  7   MaxHR           50 non-null     int64
#  8   ExerciseAngina  50 non-null     object
#  9   Oldpeak         50 non-null     float64
#  10  ST_Slope        50 non-null     object
#  11  HeartDisease    50 non-null     int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 5.1+ KB

# %%
data.shape[0]
# Out:
# 918

# %%
female.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/721758032.py in <module>
# ----> 1 female.shape()
#
# TypeError: 'tuple' object is not callable

# %%
female.shape[0]
# Out:
# 50

# %%
"data[(data['Sex'] == 'F')  & (data['HeartDisease'] == 1)]".shape[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11988/341159683.py in <module>
# ----> 1 "data[(data['Sex'] == 'F')  & (data['HeartDisease'] == 1)]".shape[0]
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
data[(data['Sex'] == 'M')  & (data['HeartDisease'] == 1)] .shape[0]
# Out:
# 458

# %%
data[(data['Sex'] == 'M') ]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 4     54   M           NAP        150          195          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# 7     54   M           ATA        110          208          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 911   59   M           ASY        164          176          1        LVH
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data[(data['Sex'] == 'M')  & (data['HeartDisease'] == 1)] .shape[0] / data[(data['Sex'] == 'M') ] .shape[0]
# Out:
# 0.6317241379310344

# %%
data[(data['Sex'] == 'F')  & (data['HeartDisease'] == 1)] .shape[0] / data[(data['Sex'] == 'F') ] .shape[0]
# Out:
# 0.25906735751295334
